# %%
import json
from python_submodule.general import info, warning, error, debug

# %%
train_data = json.load(open("data/train_with_timestamps.json"))
test_data = json.load(open("data/test_with_timestamps.json"))
metadata = json.load(open("data/thinned_poi_metadata.json"))

# %%
info(len(train_data))
# Out:
# INFO   675267

# %%
for e in range(10):
    info(train_data[e], txt=f"training data {e}")
# Out:
# training data 0   {'sample_id': 0, 'history_events': [{'item_id': 1, 'raw_location_id': 608105, 'timestamp': '2010-05-22T02:49:04Z'}], 'target_event': {'item_id': 2, 'raw_location_id': 8977, 'timestamp': '2010-05-22T17:50:55Z'}}
# training data 1   {'sample_id': 1, 'history_events': [{'item_id': 1, 'raw_location_id': 608105, 'timestamp': '2010-05-22T02:49:04Z'}, {'item_id': 2, 'raw_location_id': 8977, 'timestamp': '2010-05-22T17:50:55Z'}], 'target_event': {'item_id': 3, 'raw_location_id': 17269, 'timestamp': '2010-05-23T16:50:50Z'}}
# training data 2   {'sample_id': 2, 'history_events': [{'item_id': 4, 'raw_location_id': 18417, 'timestamp': '2010-05-31T20:10:37Z'}], 'target_event': {'item_id': 5, 'raw_location_id': 480992, 'timestamp': '2010-06-01T14:38:22Z'}}
# ...

# %%
for e in range(5):
    info(test_data[e], txt=f"test data {e}")
# Out:
# test data 0   {'sample_id': 0, 'history_events': [{'item_id': 2874, 'raw_location_id': 17526, 'timestamp': '2010-09-11T18:05:27Z'}], 'target_event': {'item_id': 445, 'raw_location_id': 19224, 'timestamp': '2010-09-11T22:48:18Z'}}
# test data 1   {'sample_id': 1, 'history_events': [{'item_id': 2874, 'raw_location_id': 17526, 'timestamp': '2010-09-11T18:05:27Z'}, {'item_id': 445, 'raw_location_id': 19224, 'timestamp': '2010-09-11T22:48:18Z'}], 'target_event': {'item_id': 1089, 'raw_location_id': 8938, 'timestamp': '2010-09-12T16:49:55Z'}}
# test data 2   {'sample_id': 2, 'history_events': [{'item_id': 2874, 'raw_location_id': 17526, 'timestamp': '2010-09-11T18:05:27Z'}, {'item_id': 445, 'raw_location_id': 19224, 'timestamp': '2010-09-11T22:48:18Z'}, {'item_id': 1089, 'raw_location_id': 8938, 'timestamp': '2010-09-12T16:49:55Z'}], 'target_event': {'item_id': 1139, 'raw_location_id': 8964, 'timestamp': '2010-09-13T01:13:03Z'}}
# ...

# %%
for e in range(5, 10):
    info(test_data[e], txt=f"test data {e}")
# Out:
# test data 5   {'sample_id': 5, 'history_events': [{'item_id': 58, 'raw_location_id': 24276, 'timestamp': '2010-09-21T02:17:22Z'}], 'target_event': {'item_id': 24, 'raw_location_id': 21714, 'timestamp': '2010-09-21T20:03:48Z'}}
# test data 6   {'sample_id': 6, 'history_events': [{'item_id': 24, 'raw_location_id': 21714, 'timestamp': '2010-09-22T22:24:27Z'}], 'target_event': {'item_id': 47, 'raw_location_id': 46946, 'timestamp': '2010-09-22T23:33:37Z'}}
# test data 7   {'sample_id': 7, 'history_events': [{'item_id': 24, 'raw_location_id': 21714, 'timestamp': '2010-09-24T14:58:57Z'}], 'target_event': {'item_id': 7, 'raw_location_id': 420315, 'timestamp': '2010-09-24T21:32:13Z'}}
# test data 8   {'sample_id': 8, 'history_events': [{'item_id': 24, 'raw_location_id': 21714, 'timestamp': '2010-09-24T14:58:57Z'}, {'item_id': 7, 'raw_location_id': 420315, 'timestamp': '2010-09-24T21:32:13Z'}], 'target_event': {'item_id': 34, 'raw_location_id': 1145567, 'timestamp': '2010-09-25T02:00:54Z'}}
# ...

# %%
for e in range(10):
    info(len(train_data[e]['history_events']), txt=f"train data {e}")
# Out:
# train data 0   1
# train data 1   2
# train data 2   1
# train data 3   2
# train data 4   3
# train data 5   1
# train data 6   2
# train data 7   3
# train data 8   4
# train data 9   5

# %%
for e in range(5):
    info(metadata[list(metadata)[e]], txt=f"metadata {e}")
# Out:
# metadata 0   {'raw_poi_id': 8938, 'latitude': 39.0528237667, 'longitude': -94.59031105, 'checkins_count_from_events': 68, 'users_count_from_events': 18, 'item_id': 1089, 'spot_latitude': 39.0528237667, 'spot_longitude': -94.59031105, 'category_id': 1, 'category_name': 'Coffee Shop', 'raw_categories': [{'url': '/categories/1', 'name': 'Coffee Shop'}], 'photos_count': 38, 'checkins_count': 438, 'users_count': 94, 'radius_meters': 50, 'highlights_count': 10, 'items_count': 10, 'max_items_count': 10, 'created_at': '2008-12-15T00:22:49Z'}
# ...
